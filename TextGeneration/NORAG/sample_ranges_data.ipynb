# %%
from sample_dataFrame_values import sample_dataframe
import pandas as pd
df = pd.read_csv("data/train_split.csv")  
data = sample_dataframe(df, seed=42)
data.to_csv("data/train_split_sampled.csv", index=False)

# %%
from sample_dataFrame_values import sample_dataframe
import pandas as pd
df = pd.read_csv("data/test_split.csv")  
data = sample_dataframe(df, seed=42)
data.to_csv("data/test_split_sampled.csv", index=False)
